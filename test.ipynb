# %%
import pandas as pd

# %%
df = pd.read_parquet("transactions_100m.parquet")

# %%
df.head()
# Out:
#    transaction_id  account_age_months  transaction_amount  \
# 0               0                  11         4810.999888
# 1               1                  93          201.804456
# 2               2                  79         2317.312662
# 3               3                  53          -99.000000
# 4               4                  52         1348.898672
#
#    raw_engagement_score region
# 0              5.828411   West
# 1              2.905668  North
# 2              1.169663  North
# 3              1.258226   West
# 4             12.349585   East

# %%
df.info
# Out:
# <bound method DataFrame.info of           transaction_id  account_age_months  transaction_amount  \
# 0                      0                  11         4810.999888
# 1                      1                  93          201.804456
# 2                      2                  79         2317.312662
# 3                      3                  53          -99.000000
# 4                      4                  52         1348.898672
# ...                  ...                 ...                 ...
# 99999995        99999995                  29         3069.657052
# 99999996        99999996                  96          791.698161
# 99999997        99999997                 105         3380.832878
# 99999998        99999998                  54         3809.878841
# 99999999        99999999                  83         2474.070056
#
#           raw_engagement_score region
# 0                     5.828411   West
# 1                     2.905668  North
# ...
